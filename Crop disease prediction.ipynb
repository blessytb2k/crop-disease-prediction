# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    "one/PlantVillage/train",
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical'
)

val_data = val_datagen.flow_from_directory(
    "one/PlantVillage/val",
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# Found 43444 images belonging to 38 classes.
# Found 10861 images belonging to 38 classes.

# %%
 # Basic libraries
import os
import numpy as np
import matplotlib.pyplot as plt

# TensorFlow / Keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing import image

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),

    Dense(128, activation='relu'),
    Dropout(0.5),

    Dense(train_data.num_classes, activation='softmax')
])

# =========================
# 4. COMPILE MODEL
# =========================
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# =========================
# 5. TRAIN MODEL
# =========================
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=10
)

# =========================
# 6. SAVE MODEL
# =========================
model.save("crop_disease_model.h5")

# =========================
# 7. PLOT ACCURACY
    
# =========================
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.show() 


# =========================
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
#   11/1358 ━━━━━━━━━━━━━━━━━━━━ 33:41 2s/step - accuracy: 0.0412 - loss: 3.8897

# %%
import pickle

# Save class indices (after training)
with open("class_indices.pkl", "wb") as f:
    pickle.dump(train_data.class_indices, f)

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import pickle

# Load the saved model
model = load_model("crop_disease_model.h5")

# Load the class indices
with open("class_indices.pkl", "rb") as f:
    class_indices = pickle.load(f)

# Convert indices to labels
labels = list(class_indices.keys())

# Load and preprocess the test image
img_path = '0b342a7e-bd8a-49b9-8121-06503160ec51___RS_HL 2669.jpg'
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0) / 255.0

# Predict
prediction = model.predict(img_array)
class_index = np.argmax(prediction)

print("Predicted Disease:", labels[class_index])
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# Predicted Disease: Blueberry___healthy

# %%
# Show class names
print("Class Names:", list(train_data.class_indices.keys()))

# Show mapping of class name → numeric label
print("Class Indices:", train_data.class_indices)
# Out:
# Class Names: ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Raspberry___healthy', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tom
# ...

# %%
disease_info = {

    #  APPLE
    "Apple___Apple_scab": {
        "description": "Fungal disease causing lesions on leaves and fruits.",
        "symptoms": "Dark olive spots on leaves, cracked fruit.",
        "treatment": "Apply fungicides like myclobutanil.",
        "prevention": "Remove fallen leaves, prune trees.",
        "solutions": "Organic: sulfur spray. Chemical: myclobutanil."
    },
    "Apple___Black_rot": {
        "description": "Fungal disease affecting fruit and leaves.",
        "symptoms": "Brown spots, fruit rot.",
        "treatment": "Remove infected parts, apply fungicide.",
        "prevention": "Sanitation, pruning.",
        "solutions": "Organic: remove infected areas. Chemical: captan."
    },
    "Apple___Cedar_apple_rust": {
        "description": "Fungal disease involving cedar trees.",
        "symptoms": "Yellow spots on leaves.",
        "treatment": "Apply fungicides.",
        "prevention": "Remove nearby cedar trees.",
        "solutions": "Organic: resistant varieties. Chemical: fungicides."
    },
    "Apple___healthy": {
        "description": "Healthy apple plant.",
        "symptoms": "No visible disease.",
        "treatment": "None needed.",
        "prevention": "Regular monitoring.",
        "solutions": "No action required."
    },

    # 🫐 BLUEBERRY
    "Blueberry___healthy": {
        "description": "Healthy blueberry plant.",
        "symptoms": "Green leaves, no spots.",
        "treatment": "None needed.",
        "prevention": "Proper care.",
        "solutions": "No action required."
    },

    #  CHERRY
    "Cherry_(including_sour)___Powdery_mildew": {
        "description": "Fungal disease affecting leaves.",
        "symptoms": "White powdery coating.",
        "treatment": "Apply fungicides.",
        "prevention": "Improve air circulation.",
        "solutions": "Organic: neem oil. Chemical: fungicides."
    },
    "Cherry_(including_sour)___healthy": {
        "description": "Healthy cherry plant.",
        "symptoms": "Normal green leaves.",
        "treatment": "None needed.",
        "prevention": "Good maintenance.",
        "solutions": "No action required."
    },

    #  CORN
    "Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot": {
        "description": "Fungal disease affecting corn leaves.",
        "symptoms": "Gray rectangular lesions.",
        "treatment": "Apply fungicides.",
        "prevention": "Crop rotation.",
        "solutions": "Organic: crop rotation. Chemical: azoxystrobin."
    },
    "Corn_(maize)___Common_rust_": {
        "description": "Fungal rust disease.",
        "symptoms": "Reddish pustules.",
        "treatment": "Apply fungicides if severe.",
        "prevention": "Resistant varieties.",
        "solutions": "Organic: proper spacing. Chemical: fungicides."
    },
    "Corn_(maize)___Northern_Leaf_Blight": {
        "description": "Fungal disease causing long lesions.",
        "symptoms": "Cigar-shaped lesions.",
        "treatment": "Use fungicides.",
        "prevention": "Crop rotation.",
        "solutions": "Organic: sanitation. Chemical: fungicides."
    },
    "Corn_(maize)___healthy": {
        "description": "Healthy corn plant.",
        "symptoms": "Green leaves.",
        "treatment": "None needed.",
        "prevention": "Proper farming.",
        "solutions": "No action required."
    },

    #  GRAPE
    "Grape___Black_rot": {
        "description": "Fungal disease affecting grapes.",
        "symptoms": "Brown leaf spots, fruit rot.",
        "treatment": "Apply fungicides.",
        "prevention": "Pruning and sanitation.",
        "solutions": "Organic: neem oil. Chemical: fungicides."
    },
    "Grape___Esca_(Black_Measles)": {
        "description": "Complex fungal disease.",
        "symptoms": "Leaf discoloration, fruit spots.",
        "treatment": "Remove infected vines.",
        "prevention": "Avoid pruning wounds.",
        "solutions": "Organic: sanitation. Chemical: fungicides."
    },
    "Grape___Leaf_blight_(Isariopsis_Leaf_Spot)": {
        "description": "Fungal leaf disease.",
        "symptoms": "Brown spots on leaves.",
        "treatment": "Apply fungicide.",
        "prevention": "Air circulation.",
        "solutions": "Organic: neem oil. Chemical: fungicides."
    },
    "Grape___healthy": {
        "description": "Healthy grape plant.",
        "symptoms": "Normal leaves.",
        "treatment": "None needed.",
        "prevention": "Proper care.",
        "solutions": "No action required."
    },

    #  ORANGE
    "Orange___Haunglongbing_(Citrus_greening)": {
        "description": "Bacterial disease spread by psyllids.",
        "symptoms": "Yellow shoots, misshapen fruits.",
        "treatment": "Remove infected trees.",
        "prevention": "Control insects.",
        "solutions": "Organic: neem oil. Chemical: insecticides."
    },

    # PEACH
    "Peach___Bacterial_spot": {
        "description": "Bacterial infection.",
        "symptoms": "Leaf spots, fruit lesions.",
        "treatment": "Copper sprays.",
        "prevention": "Resistant varieties.",
        "solutions": "Organic: copper spray. Chemical: bactericides."
    },
    "Peach___healthy": {
        "description": "Healthy peach plant.",
        "symptoms": "No disease.",
        "treatment": "None needed.",
        "prevention": "Regular care.",
        "solutions": "No action required."
    },

    #  PEPPER
    "Pepper,_bell___Bacterial_spot": {
        "description": "Bacterial disease affecting peppers.",
        "symptoms": "Dark leaf spots.",
        "treatment": "Copper sprays.",
        "prevention": "Avoid wet conditions.",
        "solutions": "Organic: copper. Chemical: bactericides."
    },
    "Pepper,_bell___healthy": {
        "description": "Healthy pepper plant.",
        "symptoms": "Green leaves.",
        "treatment": "None needed.",
        "prevention": "Good irrigation.",
        "solutions": "No action required."
    },

    #  POTATO
    "Potato___Early_blight": {
        "description": "Fungal disease affecting leaves.",
        "symptoms": "Target spots, yellowing.",
        "treatment": "Use fungicides.",
        "prevention": "Crop rotation.",
        "solutions": "Organic: neem oil. Chemical: mancozeb."
    },
    "Potato___Late_blight": {
        "description": "Serious fungal disease.",
        "symptoms": "Dark lesions, rot.",
        "treatment": "Remove infected plants.",
        "prevention": "Avoid humidity.",
        "solutions": "Organic: copper spray. Chemical: fungicides."
    },
    "Potato___healthy": {
        "description": "Healthy potato plant.",
        "symptoms": "No disease.",
        "treatment": "None needed.",
        "prevention": "Soil health.",
        "solutions": "No action required."
    },

    #  STRAWBERRY
    "Strawberry___Leaf_scorch": {
        "description": "Fungal disease.",
        "symptoms": "Brown leaf edges.",
        "treatment": "Apply fungicide.",
        "prevention": "Remove debris.",
        "solutions": "Organic: neem oil. Chemical: fungicides."
    },
    "Strawberry___healthy": {
        "description": "Healthy strawberry plant.",
        "symptoms": "Green leaves.",
        "treatment": "None needed.",
        "prevention": "Good care.",
        "solutions": "No action required."
    },

    #  TOMATO (Many Classes)
    "Tomato___Bacterial_spot": {
        "description": "Bacterial infection.",
        "symptoms": "Leaf spots, fruit lesions.",
        "treatment": "Copper sprays.",
        "prevention": "Avoid overhead watering.",
        "solutions": "Organic: copper. Chemical: bactericides."
    },
    "Tomato___Early_blight": {
        "description": "Fungal disease.",
        "symptoms": "Target spots.",
        "treatment": "Fungicides.",
        "prevention": "Crop rotation.",
        "solutions": "Organic: neem oil. Chemical: mancozeb."
    },
    "Tomato___Late_blight": {
        "description": "Severe fungal disease.",
        "symptoms": "Dark lesions.",
        "treatment": "Remove infected plants.",
        "prevention": "Avoid humidity.",
        "solutions": "Organic: copper spray. Chemical: fungicides."
    },
    "Tomato___Leaf_Mold": {
        "description": "Fungal disease in humid areas.",
        "symptoms": "Yellow spots.",
        "treatment": "Fungicides.",
        "prevention": "Ventilation.",
        "solutions": "Organic: neem oil. Chemical: fungicides."
    },
    "Tomato___Septoria_leaf_spot": {
        "description": "Fungal disease.",
        "symptoms": "Small circular spots.",
        "treatment": "Fungicides.",
        "prevention": "Avoid wet leaves.",
        "solutions": "Organic: compost tea. Chemical: fungicides."
    },
    "Tomato___Spider_mites Two-spotted_spider_mite": {
        "description": "Pest infestation.",
        "symptoms": "Yellow speckles, webbing.",
        "treatment": "Insecticides.",
        "prevention": "Maintain humidity.",
        "solutions": "Organic: neem oil. Chemical: miticides."
    },
    "Tomato___Target_Spot": {
        "description": "Fungal disease.",
        "symptoms": "Dark spots.",
        "treatment": "Fungicides.",
        "prevention": "Air circulation.",
        "solutions": "Organic: neem oil. Chemical: fungicides."
    },
    "Tomato___Tomato_Yellow_Leaf_Curl_Virus": {
        "description": "Viral disease spread by whiteflies.",
        "symptoms": "Yellow curled leaves.",
        "treatment": "Remove infected plants.",
        "prevention": "Control whiteflies.",
        "solutions": "Organic: neem oil. Chemical: insecticides."
    },
    "Tomato___Tomato_mosaic_virus": {
        "description": "Viral disease.",
        "symptoms": "Mosaic leaf pattern.",
        "treatment": "Remove infected plants.",
        "prevention": "Sanitize tools.",
        "solutions": "Organic: sanitation. Chemical: none effective."
    },
    "Tomato___healthy": {
        "description": "Healthy tomato plant.",
        "symptoms": "Green leaves.",
        "treatment": "None needed.",
        "prevention": "Proper care.",
        "solutions": "No action required."
    }
}

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import pickle

# Load model
model = load_model("crop_disease_model.h5")

# Load class indices
with open("class_indices.pkl", "rb") as f:
    class_indices = pickle.load(f)

labels = list(class_indices.keys())

# Load test image
img_path = 'RS_Rust 1565.jpg'
img = image.load_img(img_path, target_size=(224,224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)/255.0

# Predict
prediction = model.predict(img_array)
class_index = np.argmax(prediction)
predicted_label = labels[class_index]

print(f"Predicted Disease: {predicted_label}")

# Show advisory info
if predicted_label in disease_info:
    info = disease_info[predicted_label]
    print("\nDisease Description:", info['description'])
    print(" Symptoms:", info['symptoms'])
    print("Treatment:", info['treatment'])
    print(" Preventive Measures:", info['prevention'])
    print(" Solutions:", info['solutions'])
else:
    print("No advisory info available for this disease.")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# Predicted Disease: Corn_(maize)___Common_rust_
#
# Disease Description: Fungal rust disease.
#  Symptoms: Reddish pustules.
# Treatment: Apply fungicides if severe.
#  Preventive Measures: Resistant varieties.
#  Solutions: Organic: proper spacing. Chemical: fungicides.
